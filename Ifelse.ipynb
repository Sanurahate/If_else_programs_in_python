# %%
a = "DoxRobotics"
if "orp" in a[5:2:-1]:
    print("orp detected")
else:
    print("orp not detected")
# Out:
# orp not detected

# %%
a = int(input('enter marks of math'))
b = int(input('enter marks of marathi'))
c = int(input('enter marks of eng'))
total = a + b+c
print("total marks is ",total)
print("avg is",total/3)
print("percentage is",total/300*100)
percentage = total/300*100
if percentage > 90:
    print("A + GRADE")
elif  percentage > 80:
    print("A GRADE") 
elif percentage > 70:
    print("B GRADE") 
elif percentage > 55:
    print("C GRADE")  
else:
    print("candidate fail")
# Out:
# total marks is  270
# avg is 90.0
# percentage is 90.0
# A GRADE

# %%
a = input("enter a color").lower()
if a.lower() == "red":
    print("you can stop")
elif a.lower() == "yellow":
    print(" you are ready") 
elif a.lower()== "green":   
    print(" you can go")  
else:
   print("invalid color entered")
# Out:
# you can stop

# %%
a = int(input("enter a number"))
if a>= 10 and a<=100:
    print(f"the number enter {a} is greater than one digit")  
elif a>= 100 and a<=1000:
    print(f"the number enter {a} is greater than two digit")  
else:
        print(f"the number enter {a} is greater than three digit")
# Out:
# the number enter 9990 is greater than three digit

# %%
a = int(input("enter the number"))
if a% 10 == 5 and a > 0:
    print(f"the number enter {a} is valid and positive")
elif a% 10 == 5 and a< 0:
    print(f"the number enter {a} is invalid and negative ")   
else:
    print("invalid number")
# Out:
# invalid number

# %%
a = int(input("enter a number"))
if a < 0:
    print(f"the number enter {a} is negative")
else:
    print(f"the number enter {a} is positive")
# Out:
# the number enter -125 is negative

# %%
balance = int(input("enter a balance"))
withdraw = int(input("enter a amount to withdraw"))
W = balance-withdraw
print("the available balance after withdraw is",W) 
if withdraw > balance:
    print("insufficient balance")
else:
    print("withdraw completed!!")
# Out:
# the available balance after withdraw is 300
# withdraw completed!!

# %%
username = input("enter a username")
pass1 = input("enter a password")
if username == 'admin' and pass1 == '1234':
     print("login successfull !")
else:
     print("invalid credentials")
# Out:
# login successfull !

# %%
num1 = int(input("enter 1st number"))
num2 = int(input("enter 2nd number"))
operator = (input("enter the operator"))
if operator == '+':
    print(f"addition of {num1} and {num2} is",(num1+num2))
elif operator == '-':
    print(f"subtraction of {num1} and {num2} is",(num1-num2))
elif operator == '*':
    print(f"multiplication of {num1} and {num2} is",(num1*num2))
elif operator == '/' :
    if num2!= 0:
     print(f"divison of {num1} and {num2} is",(num1/num2))
elif operator == '%':
     print(f"reminder of {num1} and {num2} is",(num1%num2))
else:
     print(f"invalid operator ({operator})")
# Out:
# divison of 10 and 2 is 5.0

# %%
sal = 10000
year = int(input("enter the year of experience"))
if year == 5 :
    bonus = sal*10/100+sal
    print("the bonus for 5 year",bonus)
elif year == 10 :
    bonus = sal*20/100+sal
    print("the bonus for 10 year ",bonus)
else :
    print("no bonus")
# Out:
# the bonus for 10 year  12000.0

# %%
x = int(input("enter x coordinate"))
y = int(input("enter y coordinate"))
if x > 0 and y > 0:
    print("Quadrant 1")
elif x < 0 and y > 0:
    print("Quadrant 2")  
elif x<0 and y<0:
    print("Quadrant 3")   
elif x >0 and y< 0:
    print("Quadrant 4") 
else :
    print("Invalid coordinate")
# Out:
# Quadrant 1

# %%
unit = int(input("enter the unit"))
if unit <=100:
    print("bill is",unit*2,'rs')
elif unit<=300:
    print("bill is",unit*4,'rs')    
else:
    print("bill is",unit*9,'rs')
# Out:
# bill is 800 rs
